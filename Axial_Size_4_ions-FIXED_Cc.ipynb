# %% [markdown]
# **Hypothesis** : Transition rate depends position of an ion relative to the 1762nm laser.
#
# Ion positions can vary from file to file which interferes with our analysis. Thus, we picked only those files in which the positions of ions were identically same.

# %%
import numpy as np
import scipy
import scipy.signal
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import stats
import scipy.stats
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
import glob
import time
import pandas as pd
import math
#import File_functions
plt.rcParams["figure.figsize"] = (3,3)



print (time.ctime())
# Out:
# Mon Jun 28 15:20:35 2021

# %%
### Call the modules that have both the File information and the functions to perform the analysis ###
import Ion_functions as func
from Ion_functions import Ion
import choose_file

# %% [markdown]
# # Four Ions

# %%
choose_file.Fions_yscan_149s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_149s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
import importlib
importlib.reload(choose_file)
choose_file.Fions_yscan_150s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_150s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.Fions_yscan_151() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_151 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.Fions_yscan_151s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty =True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_151s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.Fions_yscan_152() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_152 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.Fions_yscan_152s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_152s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.Fions_yscan_153() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_yscan_153 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
#plotting transition rate for each ion while varying the axial position of the beam  


beam_apositions=np.array([149.5, 150.5,151.5,152,152.5])
rate=[]

for i in range (4):
    
    rates_yscan=np.array([rates_yscan_149s[i],rates_yscan_150s[i],rates_yscan_151s[i],rates_yscan_152[i],rates_yscan_152s[i]])
    rate.append(rates_yscan) 
    print (rates_yscan)
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_apositions, rates_yscan)
    ax.set_xlabel("Beam Axial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
# Out:
# [10.7219419  12.95522704 21.9671004  15.46333882 15.7043823 ]
# [14.78410539 17.66347846 27.21630327 21.40521414 19.03086697]
# [18.64135262 16.5060082  25.36009835 18.8741922  16.96386653]
# [16.76697154 12.28003605 20.23745491 13.51686242 10.49168442]

# %%
## ion2 => i=1
#plotting transition rate for each ion while varying the axial position of the beam  


beam_apositions_2=np.array([149.5, 150.5,151,151.5,152])
rate_2=[]

for i in range (1,2):
    
    rates_yscan=np.array([rates_yscan_149s[i],rates_yscan_150s[i],rates_yscan_151[i],rates_yscan_151s[i],rates_yscan_152[i]])
    rate_2.append(rates_yscan) 
    print (rates_yscan)
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_apositions_2, rate_2)
    ax.set_xlabel("Beam Axial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
# Out:
# [14.78410539 17.66347846 21.17126575 27.21630327 21.40521414]

# %%
#ion3=> i=2
beam_apositions_3=np.array([149.5, 150.5,151,151.5])
rate_3=[]

for i in range (2,3):
    
    rates_yscan=np.array([rates_yscan_149s[i],rates_yscan_150s[i],rates_yscan_151[i],rates_yscan_151s[i]])
    rate_3.append(rates_yscan) 
    print (rates_yscan)
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_apositions_3, rate_3)
    ax.set_xlabel("Beam Axial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
# Out:
# [18.64135262 16.5060082  19.97732937 25.36009835]

# %%
#ion4=> i=3
beam_apositions_4=np.array([149.5, 150.5,151,151.5,152,152.5])
rate_4=[]

for i in range (3,4):
    
    rates_yscan=np.array([rates_yscan_149s[i],rates_yscan_150s[i],rates_yscan_151[i],rates_yscan_151s[i],rates_yscan_152[i],rates_yscan_152s[i]])
    rate_4.append(rates_yscan) 
    print (rates_yscan)
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_apositions_4, rate_4)
    ax.set_xlabel("Beam Axial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
# Out:
# [16.76697154 12.28003605 16.69098934 20.23745491 13.51686242 10.49168442]

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5, 5))
ax.scatter(beam_apositions, rate[0], label = 'Ion 1', color = 'm')
ax.scatter(beam_apositions_2, rate_2[0], label = 'Ion 2', color = 'b')
#ax.scatter(beam_apositions_3, rate_3[0], label = 'Ion 3', color = 'y')
ax.scatter(beam_apositions_4, rate_4[0], label = 'Ion 4', color = 'g')
ax.legend()

popt, pcov = curve_fit(func.Gaussian, beam_apositions, rate[0], p0 = [152, 1, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(145,157,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt)
sigma.append(popt[1])

popt, pcov = curve_fit(func.Gaussian, beam_apositions_2, rate_2[0], p0 = [152, 1, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(145,157,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt)
sigma.append(popt[1])

"""popt, pcov = curve_fit(func.Gaussian, beam_apositions_3, rate_3[0], p0 = [152, 1, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(145,157,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'y')
print(popt)
sigma.append(popt[1])
"""
popt, pcov = curve_fit(func.Gaussian, beam_apositions_4, rate_4[0], p0 = [152, 1, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(145,157,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'g')
print(popt)
sigma.append(popt[1])


plt.legend()
plt.xlabel("beam axial positions")
plt.ylabel("transition rates")
# Out:
# [1.51495826e+02 1.71822626e+00 1.83260012e+01 9.99999999e-02]
# [1.51780412e+02 2.19500104e+00 2.33587650e+01 9.99999999e-02]
# [ 1.50557862e+02  2.45044010e+00  1.68012791e+01 -1.00000000e-01]
# Text(0, 0.5, 'transition rates')

# %%
print (sigma,"s",width,"w")

# %%
print (width)
# Out:
# [4.046113647894765]

# %%
width=[]
def sigma2fwhm(sigma):
    width.append(sigma * np.sqrt(8 * np.log(2)))
  
for i in range (1):
    sigma2fwhm(sigma[i])
