# %% [markdown]
# **Hypothesis** : Transition rate depends position of an ion relative to the 1762nm laser.
# ------------
# Ion positions can vary from file to file which interferes with our analysis. Thus, we picked only those files in which the positions of ions were identically same while the beam was moved *radially*.

# %%
import numpy as np
import scipy
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import stats
import scipy.stats
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
import glob
import time
import pandas as pd
import math
#import File_functions
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())

import Ion_functions as func
from Ion_functions import Ion
import choose_file
# Out:
# Sun Jun 27 14:34:55 2021

# %%
import importlib
importlib.reload(choose_file)

choose_file.Two_ions_xscan_399s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_399s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
choose_file.Two_ions_xscan_400s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_400s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
choose_file.Two_ions_xscan_401s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_401s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]
xs_401s = [ion_1.x, ion_2.x]
ys_401s = [ion_1.y, ion_2.y]

# %%
choose_file.Two_ions_xscan_402s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_402s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
choose_file.Two_ions_xscan_403() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_403 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
choose_file.Two_ions_xscan_403s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_403s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
choose_file.Two_ions_xscan_404() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2

Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)

rates_xscan_404= [len(ion_1.transpts)/time, len(ion_2.transpts)/time]

# %%
###x1=48

beam_rpositions=np.array([399.5,401.5,403.5,404])
rate=[]
for i in range (1):
    
    rates_xscan=np.array([rates_xscan_399s[i],rates_xscan_401s[i],rates_xscan_403s[i],rates_xscan_404[i]])
    rate.append(rates_xscan) 
    
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_rpositions, rate[0])
    ax.set_xlabel("Beam Radial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5,5))
ax.scatter(beam_rpositions, rate[0], label = 'Ion 1', color = 'm')
#ax.scatter(beam_rpositions, rate[1], label = 'Ion 2', color = 'b')

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[0], p0 = [395, 1, 27, 0], 
                       bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(392, 410, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt)
sigma.append(popt[1])


plt.legend()
plt.xlabel("beam radial positions")
plt.ylabel("transition rates_Ion_1")
# Out:
# [4.01560857e+02 2.76615654e+00 2.66115908e+01 1.00000000e-01]
# C:\Users\akank\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Text(0, 0.5, 'transition rates_Ion_1')

# %%
width=[]
def sigma2fwhm(sigma):
    width.append(sigma * np.sqrt(8 * np.log(2)))
    
for i in range (1):
    sigma2fwhm(sigma[i])
print (width)
# Out:
# [6.5138008714351905]

# %%
###x2 = 62

beam_rpositions_2=np.array([400.5,402.5,403,404])
rate_2=[]
for i in range (1,2):
    
    rates_xscan=np.array([rates_xscan_400s[i],rates_xscan_402s[i],rates_xscan_403[i],rates_xscan_404[i]])
    rate_2.append(rates_xscan) 
    
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_rpositions_2, rate_2)
    ax.set_xlabel("Beam Radial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
    
print (rate_2)
# Out:
# [array([17.48710966, 23.15305776, 18.39166856, 15.60512968])]

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5,5))
#ax.scatter(beam_rpositions, rate[0], label = 'Ion 1', color = 'm')
ax.scatter(beam_rpositions_2, rate_2[0], label = 'Ion 2', color = 'b')

popt, pcov = curve_fit(func.Gaussian, beam_rpositions_2, rate_2[0], p0 = [400, 3, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(392, 410, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt)
sigma.append(popt[1])


plt.legend()
plt.xlabel("beam radial positions")
plt.ylabel("transition rates_Ion_2")
# Out:
# [4.02021453e+02 2.22582345e+00 2.21509207e+01 1.00000000e-01]
# C:\Users\akank\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Text(0, 0.5, 'transition rates_Ion_2')

# %%
width=[]
def sigma2fwhm(sigma):
    width.append(sigma * np.sqrt(8 * np.log(2)))
    
for i in range (1):
    sigma2fwhm(sigma[i])
print (width)
# Out:
# [5.241413670069946]

# %% [markdown]
# Here's what the x vs time graph looks like for three of seven files
# (see Jumps_Data_Pandas_2ions_xscan):
#
# ![image.png](attachment:image.png) x_399.5
#
# ![image.png](attachment:image.png) x_400.5
#
# ![image.png](attachment:image.png) x_404

# %%
#Graphs as a function of  position of beam 

beam_rpositions=np.array([401.5,402.5,403,403.5])
rate=[]
for i in range (2):
    
    rates_xscan=np.array([rates_xscan_401s[i],rates_xscan_402s[i],rates_xscan_403[i],rates_xscan_403s[i]])
    rate.append(rates_xscan) 
    
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_rpositions, rates_xscan)
    ax.set_xlabel("Beam Radial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')
    ax.set_xticks(beam_rpositions)

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5,5))
ax.scatter(beam_rpositions, rate[0], label = 'Ion 1', color = 'm')
ax.scatter(beam_rpositions, rate[1], label = 'Ion 2', color = 'b')

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[0], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt[1])
sigma.append(popt[1])

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[1], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt[1])
sigma.append(popt[1])


plt.legend()
plt.xlabel("beam radial positions")
plt.ylabel("transition rates")
