# %% [markdown]
# # Jumps Data Analysis
# This Notebook is designed to perform analysis on single ions from single datasets. Most methods provide figures that help to display differences in behavior by different ions in the chain.
#
# Datasets are selected using **choose_file.py** which automatically differentiates each ion by their previously identified locations.
#
# It pulls from both **Ion_functions.py** to do analysis on each of the ions.
#
# Since the number of ions is fairly large, radial width is reduced to 3 pixels to minimize cross-talk while keeping the region large enough to keep uncertainty in transition point low.

# %%
import numpy as np
import scipy
import scipy.signal
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import stats
import scipy.stats
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
import glob
import time
import pandas as pd
import math
#import File_functions
plt.rcParams["figure.figsize"] = (3,3)




print (time.ctime())
# Out:
# Thu Jun 17 15:56:54 2021

# %%
### Call the modules that have both the File information and the functions to perform the analysis ###
import Ion_functions as func
from Ion_functions import Ion
import choose_file

# %%
choose_file.Sevenions_335_370V__1() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
ion_5 = choose_file.ion_5
ion_6 = choose_file.ion_6
ion_7 = choose_file.ion_7
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4
Ion_5 = choose_file.Ion_5
Ion_6 = choose_file.Ion_6
Ion_7 = choose_file.Ion_7



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma,uncertainty, single_photon)
ion_2.setup(sigma,uncertainty, single_photon)
ion_3.setup(sigma,uncertainty, single_photon)
ion_4.setup(sigma,uncertainty, single_photon)
ion_5.setup(sigma,uncertainty, single_photon)
ion_6.setup(sigma,uncertainty, single_photon)
ion_7.setup(sigma,uncertainty, single_photon)


xposition_11=[ion_1.x,ion_2.x,ion_3.x,ion_4.x,ion_5.x,ion_6.x,ion_7.x]
rate_11= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time,len(ion_5.transpts)/time,len(ion_6.transpts)/time,len(ion_7.transpts)/time]

# %%
choose_file.Sevenions_335_370V__2() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
ion_5 = choose_file.ion_5
ion_6 = choose_file.ion_6
ion_7 = choose_file.ion_7
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4
Ion_5 = choose_file.Ion_5
Ion_6 = choose_file.Ion_6
Ion_7 = choose_file.Ion_7



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)
ion_5.setup(sigma, uncertainty, single_photon)
ion_6.setup(sigma, uncertainty, single_photon)
ion_7.setup(sigma, uncertainty, single_photon)


rate_12= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time,len(ion_5.transpts)/time,len(ion_6.transpts)/time,len(ion_7.transpts)/time]
xposition_12=[ion_1.x,ion_2.x,ion_3.x,ion_4.x,ion_5.x,ion_6.x,ion_7.x]

# %%
choose_file.Sevenions_239_2580V__1() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
ion_5 = choose_file.ion_5
ion_6 = choose_file.ion_6
ion_7 = choose_file.ion_7
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4
Ion_5 = choose_file.Ion_5
Ion_6 = choose_file.Ion_6
Ion_7 = choose_file.Ion_7



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)
ion_5.setup(sigma, uncertainty, single_photon)
ion_6.setup(sigma, uncertainty, single_photon)
ion_7.setup(sigma, uncertainty, single_photon)


rate_13= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time,len(ion_5.transpts)/time,len(ion_6.transpts)/time,len(ion_7.transpts)/time]
xposition_13=[ion_1.x,ion_2.x,ion_3.x,ion_4.x,ion_5.x,ion_6.x,ion_7.x]

# %%
choose_file.Sevenions_239_2580V__2() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
ion_5 = choose_file.ion_5
ion_6 = choose_file.ion_6
ion_7 = choose_file.ion_7
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4
Ion_5 = choose_file.Ion_5
Ion_6 = choose_file.Ion_6
Ion_7 = choose_file.Ion_7



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)
ion_5.setup(sigma, uncertainty, single_photon)
ion_6.setup(sigma, uncertainty, single_photon)
ion_7.setup(sigma, uncertainty, single_photon)


rate_14= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time,len(ion_5.transpts)/time,len(ion_6.transpts)/time,len(ion_7.transpts)/time]
xposition_14=[ion_1.x,ion_2.x,ion_3.x,ion_4.x,ion_5.x,ion_6.x,ion_7.x]

# %%
#Plots of transition rates for each ion 

fig, ax1 = plt.subplots(1, figsize = (3,3))
ax1.scatter(xposition_11, rate_11)
ax1.set_xlabel("Radial Position-370V-I")
ax1.set_ylabel("Transition Rate")

fig, ax2 = plt.subplots(1, figsize = (3,3))
ax2.scatter(xposition_12, rate_12)
ax2.set_xlabel("Radial Position-370V-II")
ax2.set_ylabel("Transition Rate")

fig, ax3 = plt.subplots(1, figsize = (3,3))
ax3.scatter(xposition_13, rate_13)
ax3.set_xlabel("Radial Position-2580V-I")
ax3.set_ylabel("Transition Rate")

fig, ax4 = plt.subplots(1, figsize = (3,3))
ax4.scatter(xposition_14, rate_14)
ax4.set_xlabel("Radial Position-2580V-II")
ax4.set_ylabel("Transition Rate")
# Out:
# Text(0, 0.5, 'Transition Rate')

# %%
#Combined plot to compare transition rates

fig, ax = plt.subplots(1, figsize = (5, 5))
ax.scatter(xposition_11, rate_11, label = '370V-I', color = 'g')
ax.scatter(xposition_12,rate_12, label = '370V-II', color = 'm')
ax.scatter(xposition_13, rate_13, label = '2580V-I', color = 'b')
ax.scatter(xposition_14, rate_14, label = '2580-II', color = 'y')


ax.legend()

popt, pcov = curve_fit(func.Gaussian, xposition_11, rate_11, p0 = [60, 15, 18, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'g')
var_370V_1=popt


popt, pcov = curve_fit(func.Gaussian,xposition_12, rate_12, p0 = [60, 15, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
var_370V_2=popt

popt, pcov = curve_fit(func.Gaussian, xposition_13, rate_13, p0 = [60, 15, 14, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt)
var_258V_1=popt

popt, pcov = curve_fit(func.Gaussian, xposition_14, rate_14, p0 = [60, 15, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'y')
var_258V_2=popt



plt.legend()
plt.xlabel("Ion Radial Positions")
plt.ylabel("Transition Rates")
# Out:
# [66.13055576 15.79150384 14.55223185  0.1       ]
# Text(0, 0.5, 'Transition Rates')

# %%
choose_file.Sevenions_370V__1() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
ion_5 = choose_file.ion_5
ion_6 = choose_file.ion_6
ion_7 = choose_file.ion_7
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4
Ion_5 = choose_file.Ion_5
Ion_6 = choose_file.Ion_6
Ion_7 = choose_file.Ion_7



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma,uncertainty, single_photon)
ion_2.setup(sigma,uncertainty, single_photon)
ion_3.setup(sigma,uncertainty, single_photon)
ion_4.setup(sigma,uncertainty, single_photon)
ion_5.setup(sigma,uncertainty, single_photon)
ion_6.setup(sigma,uncertainty, single_photon)
ion_7.setup(sigma,uncertainty, single_photon)


xposition_00=[ion_1.x,ion_2.x,ion_3.x,ion_4.x,ion_5.x,ion_6.x,ion_7.x]
rate_00= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time,len(ion_5.transpts)/time,len(ion_6.transpts)/time,len(ion_7.transpts)/time]

# %%
fig, ax0 = plt.subplots(1, figsize = (5, 5))
ax0.scatter(xposition_11, rate_11, label = '370V-I', color = 'g')
ax0.scatter(xposition_12,rate_12, label = '370V-II', color = 'm')
ax0.scatter(xposition_13, rate_13, label = '2580V-I', color = 'b')
ax0.scatter(xposition_14, rate_14, label = '2580-II', color = 'y')
ax0.scatter(xposition_00, rate_00, label = '370v_0', color = 'cyan')


ax.legend()

popt, pcov = curve_fit(func.Gaussian, xposition_11, rate_11, p0 = [60, 15, 18, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'g')
print(popt)


popt, pcov = curve_fit(func.Gaussian,xposition_12, rate_12, p0 = [60, 15, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt)

popt, pcov = curve_fit(func.Gaussian, xposition_13, rate_13, p0 = [60, 15, 14, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt)


popt, pcov = curve_fit(func.Gaussian, xposition_14, rate_14, p0 = [60, 15, 20, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'y')
print(popt)

popt, pcov = curve_fit(func.Gaussian, xposition_00, rate_00, p0 = [60, 15, 18, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(1,120,0.1)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'cyan')

var_370V_0=popt


plt.legend()
plt.xlabel("Ion Radial Positions")
plt.ylabel("Transition Rates")
# Out:
# [66.74650165 18.31508211 17.55014637 -0.1       ]
# [66.09304944 18.07207435 20.0586183  -0.1       ]
# [66.13055576 15.79150384 14.55223185  0.1       ]
# [65.72076763 18.54436607 21.04548033  0.1       ]
# Text(0, 0.5, 'Transition Rates')

# %%
import statistics as st

# %%
#Finding average amplitude and standard deviation
A_258V = (var_258V_1[2]+var_258V_2[2])/(2)
Std_258V=st.stdev([var_258V_1[2],var_258V_2[2]])

A_370V_12 = (var_370V_1[2]+var_370V_2[2])/(2)
Std_370V_12=st.stdev([var_370V_1[2],var_370V_2[2]])/(2)

A_370V_02 = (var_370V_0[2]+var_370V_2[2])/(2)
Std_370V_02=st.stdev([var_370V_0[2],var_370V_2[2]])/(2)


print (A_258V,Std_258V,": 258V"),
print (A_370V_12,Std_370V_12," : 370V"),
print (A_370V_02,Std_370V_02,": 370V original")
# Out:
# 17.798856092643337 4.591420033930705 : 258V
# 18.80438233464056 0.886878755121454  : 370V
# 18.600950804736488 1.0307265694237777 : 370V original
