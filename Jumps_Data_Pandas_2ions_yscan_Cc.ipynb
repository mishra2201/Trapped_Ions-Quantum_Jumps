# %% [markdown]
# ###### This file takes raw data and locates the center of ions for a system of 2 ions.

# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
import pandas as pd
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Mon Jun 21 20:55:48 2021

# %%
# This cell is used to see an image of the ions. Helpful to make sure ions did not move (blurry) and that there weren't spatial errors 
# Helpful also to identify the locaitons of the ions.
plt.figure(figsize=(10, 10))

it = pd.read_csv('yscan_153s')
n=2
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
#x_guess = 40
#y_guess = 85
plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


"""r = pd.DataFrame() 
for i in range (1,n+1):
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    r=r.append(temp[["x",'y']].mode())
r.reset_index(drop=True, inplace=True)
   
    
x1=r["x"][0]; y1=r["y"][0]
x2=r["x"][1]; y2=r["y"][1]

print (x1,y1),;print (x2,y2)"""

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)
    
x1 = 48; y1 = 92
x2 = 62; y2 = 92



#plt.savefig('Ions.svg')
# Out:
# 48.0 92.0
# 62.0 92.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10, 10))
it = pd.read_csv('yscan_154s')
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

n=2

plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)

x1 = 48; y1 = 92
x2 = 62; y2 = 92
# Out:
# 48.0 91.0
# 62.0 92.0

# %%
plt.figure(figsize=(10, 10))
#filename = 'yscan_154'
it = pd.read_csv('yscan_154')

plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

n=2

plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)

#---------------------------------------------------------------
x10 = 48; y10 = 92
x20 = 62; y20 = 92
# Out:
# 48.0 92.0
# 62.0 92.0

# %%
plt.figure(figsize=(10, 10))
filename = 'yscan_155s'
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

n=2

plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)

x10 = 49; y10 = 92
x20 = 62; y20 = 92



#
# Out:
# 49.0 91.0
# 62.0 92.0

# %%
plt.figure(figsize=(10, 10))
filename = 'yscan_156'
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

n=2

plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)

x10 = 49; y10 = 92
x20 = 62; y20 = 93
# Out:
# 49.0 92.0
# 62.0 92.0

# %%
plt.figure(figsize=(10, 10))
filename = 'yscan_155'
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

n=2

plt.xlim(40,70)
plt.ylim(80, 110)
                                                                           #fitting each ion within a box of width f 
grid_x=np.linspace(40,70,3)
plt.xticks(grid_x)
plt.grid()


a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
x2=a[1][0]; y2=a[1][1]

print (x1,y1),;print (x2,y2)
# Out:
# 49.0 93.0
# 62.0 92.0
