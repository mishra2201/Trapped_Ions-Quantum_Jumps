# %% [markdown]
# **Hypothesis**: Transition rates are affected by the position of ions relative to the 1762nm lazer. Graph at the bottom tests this hypothesis fot ion 1 and ion 4 only.

# %%
import numpy as np
import scipy
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import stats
import scipy.stats
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
import glob
import time
import pandas as pd
import math
#import File_functions
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())

import Ion_functions as func
from Ion_functions import Ion
import choose_file 
import importlib
importlib.reload(choose_file)
# Out:
# Mon Jun 28 15:14:10 2021
# <module 'choose_file' from 'C:\\Users\\akank\\Desktop\\Superradiance\\choose_file.py'>

# %%
choose_file.xscan_401s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_401s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]
xs_401s = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_401s = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

# %%
choose_file.xscan_402() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_402 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]
xs_402 = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_402 = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

# %%
choose_file.xscan_402s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_402s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]
xs_402s = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_402s = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

# %%
choose_file.xscan_403() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_403 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]

# %%
choose_file.xscan_403s() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_403s = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]
xs_403s = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_403s = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

# %%
choose_file.xscan_404() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4
Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4



filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = True
single_photon = False
ion_1.setup(sigma, uncertainty, single_photon)
ion_2.setup(sigma, uncertainty, single_photon)
ion_3.setup(sigma, uncertainty, single_photon)
ion_4.setup(sigma, uncertainty, single_photon)

rates_xscan_404 = [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, len(ion_4.transpts)/time]
xs_404 = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_404 = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

# %%
#Graphs as a function of  position of beam 

beam_rpositions=np.array([401.5, 402, 403.5,404])
rate=[]
for i in range (4):
    
    rates_xscan=np.array([rates_xscan_401s[i],rates_xscan_402[i],rates_xscan_403s[i],rates_xscan_404[i]])
    rate.append(rates_xscan) 
    
    fig, ax = plt.subplots(1, figsize = (5, 5))
    ax.scatter(beam_rpositions, rates_xscan)
    ax.set_xlabel("Beam Radial Position")
    ax.set_ylabel("Transition Rate")
    ax.set_title(f'Ion {i+1}')

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5,5))
ax.scatter(beam_rpositions, rate[0], label = 'Ion 1', color = 'm')
#ax.scatter(beam_rpositions, rate[1], label = 'Ion 2', color = 'b')
#ax.scatter(beam_rpositions, rate[2], label = 'Ion 3', color = 'y')
ax.scatter(beam_rpositions, rate[3], label = 'Ion 4', color = 'g')

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[0], p0 = [402.5, 1.1, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt[1])
sigma.append(popt[1])

"""popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[1], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt[1])
sigma.append(popt[1])"""

"""popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[2], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'y')
print(popt[1])
sigma.append(popt[1])"""

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[3], p0 = [402.5, 1.1, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'g')
sigma.append(popt[1])

print(popt[1])


plt.legend()
plt.xlabel("beam radial positions")
plt.ylabel("transition rates")
# Out:
# 1.103763804135146
# 1.4205143223430328
# C:\Users\akank\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# C:\Users\akank\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Text(0, 0.5, 'transition rates')

# %%
print (sigma)
width=[]
def sigma2fwhm(sigma):
    width.append(sigma * np.sqrt(8 * np.log(2)))
  
for i in range (2):
    sigma2fwhm(sigma[i])
print (width)
# Out:
# [1.103763804135146, 1.4205143223430328]
# [2.5991651309570565, 3.345055600506929]

# %%
sigma=[]
fig, ax = plt.subplots(1, figsize = (5,5))
ax.scatter(beam_rpositions, rate[0], label = 'Ion 1', color = 'm')
ax.scatter(beam_rpositions, rate[1], label = 'Ion 2', color = 'b')
ax.scatter(beam_rpositions, rate[2], label = 'Ion 3', color = 'y')
ax.scatter(beam_rpositions, rate[3], label = 'Ion 4', color = 'g')

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[0], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'm')
print(popt[1])
sigma.append(popt[1])

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[1], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'b')
print(popt[1])
sigma.append(popt[1])

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[2], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'y')
print(popt[1])
sigma.append(popt[1])

popt, pcov = curve_fit(func.Gaussian, beam_rpositions, rate[3], p0 = [402.5, 0.5, 25, 0], bounds = ([-np.inf, -np.inf, -np.inf, -.1], [np.inf, np.inf, np.inf, .1]))
x = np.arange(398, 408, .01)
y = func.Gaussian(x, *popt)
plt.plot(x, y, 'g')
sigma.append(popt[1])

print(popt[1])


plt.legend()
plt.xlabel("beam radial positions")
plt.ylabel("transition rates")
